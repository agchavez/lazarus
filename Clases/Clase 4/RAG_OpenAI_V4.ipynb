# %% [markdown]
# # 🚀 RAG OpenAI V4 - Integración con FastAPI
#
# ## De Notebook a API REST Profesional
#
# En esta versión V4, llevamos nuestro agente RAG al siguiente nivel integrándolo con **FastAPI**, lo que nos permite:
#
# ### ✨ Novedades en V4:
#
# 1. **API REST Profesional**: Endpoints HTTP para consumir el agente desde cualquier aplicación
# 2. **Múltiples Sesiones**: Gestión de conversaciones independientes por usuario
# 3. **Persistencia de Historial**: Mantenimiento del contexto entre peticiones
# 4. **Integración Web**: Consumo desde aplicaciones HTML/JavaScript
# 5. **Estadísticas en Tiempo Real**: Monitoreo del uso del sistema
# 6. **Dashboard CRM**: Análisis de clientes y oportunidades de venta
# 7. **Escalabilidad**: Base para despliegue en producción
#
# ---

# %% [markdown]
# ## 📦 Instalación de Dependencias
#
# Para ejecutar la API necesitamos instalar las siguientes librerías:
#
# - **FastAPI**: Framework web moderno y rápido para construir APIs
# - **Uvicorn**: Servidor ASGI de alto rendimiento para ejecutar FastAPI
# - **Requests**: Para hacer peticiones HTTP desde Python
# - **Python-multipart**: Para manejar formularios y archivos en FastAPI
#
# Además, asegúrate de tener instaladas las dependencias de las versiones anteriores:
# - `openai`
# - `langchain`
# - `langchain-openai`
# - `chromadb`
# - `python-dotenv`

# %%
# Instalación de dependencias nuevas para V4
# !pip install fastapi uvicorn[standard] requests python-multipart

# Si aún no tienes las dependencias anteriores:
# !pip install openai langchain langchain-openai chromadb python-dotenv

# %% [markdown]
# ## 🌐 ¿Qué es una API REST?
#
# Una **API REST** (Representational State Transfer) es una interfaz que permite la comunicación entre aplicaciones a través de HTTP. En lugar de ejecutar nuestro agente RAG directamente en un notebook, lo exponemos como un servicio web que puede ser consumido por:
#
# - 🌐 Aplicaciones web (HTML/JavaScript)
# - 📱 Aplicaciones móviles
# - 🐍 Scripts de Python
# - 🔗 Otros servicios y microservicios
#
# ### Ventajas de usar FastAPI:
#
# 1. **Alto rendimiento**: Una de las frameworks más rápidas de Python
# 2. **Validación automática**: Verifica tipos de datos automáticamente
# 3. **Documentación automática**: Genera Swagger UI y ReDoc
# 4. **Async/Await**: Soporte nativo para operaciones asíncronas
# 5. **Type hints**: Usa anotaciones de tipo de Python
#
# ---

# %% [markdown]
# ## 🚀 Ejecutar la API
#
# Para iniciar el servidor FastAPI, ejecuta el siguiente comando en tu terminal (NO en el notebook):
#
# ```bash
# uvicorn api_rag:app --reload --host 0.0.0.0 --port 8000
# ```
#
# ### Parámetros explicados:
#
# - **`api_rag:app`**: Módulo `api_rag.py` y la instancia `app` de FastAPI
# - **`--reload`**: Reinicia automáticamente al detectar cambios en el código (solo para desarrollo)
# - **`--host 0.0.0.0`**: Permite conexiones desde cualquier IP (no solo localhost)
# - **`--port 8000`**: Puerto donde escuchará el servidor
#
# ### URLs importantes:
#
# - **API**: http://localhost:8000
# - **Documentación Swagger**: http://localhost:8000/docs
# - **Documentación ReDoc**: http://localhost:8000/redoc
#
# ⚠️ **Nota**: Asegúrate de tener el archivo `api_rag.py` en el mismo directorio y de haber configurado tu archivo `.env` con la `OPENAI_API_KEY`.

# %%
# Este código muestra el comando, pero debes ejecutarlo en una terminal externa
# NO ejecutes servidores web directamente en Jupyter Notebooks en producción

print("Para iniciar la API, ejecuta en tu terminal:")
print("")
print("uvicorn api_rag:app --reload --host 0.0.0.0 --port 8000")
print("")
print("Luego visita: http://localhost:8000/docs")

# %% [markdown]
# ## 🔌 Endpoints Disponibles
#
# Nuestra API expone los siguientes endpoints:
#
# ### 1. **POST /chat** - Enviar mensaje al agente
# Envía un mensaje al agente RAG y recibe una respuesta.
#
# **Body**:
# ```json
# {
#   "message": "¿Cuáles son los productos disponibles?",
#   "session_id": "user_123"
# }
# ```
#
# **Respuesta**:
# ```json
# {
#   "response": "Tenemos los siguientes productos...",
#   "session_id": "user_123"
# }
# ```
#
# ---
#
# ### 2. **DELETE /chat/history/{session_id}** - Limpiar historial
# Elimina el historial de conversación de una sesión específica.
#
# **Respuesta**:
# ```json
# {
#   "message": "Historial eliminado exitosamente",
#   "session_id": "user_123"
# }
# ```
#
# ---
#
# ### 3. **POST /chat/new** - Nueva sesión
# Crea una nueva sesión de chat limpia.
#
# **Body**:
# ```json
# {
#   "message": "Hola, necesito información"
# }
# ```
#
# **Respuesta**:
# ```json
# {
#   "response": "¡Hola! ¿En qué puedo ayudarte?",
#   "session_id": "nuevo_id_generado"
# }
# ```
#
# ---
#
# ### 4. **GET /stats** - Estadísticas del sistema
# Obtiene estadísticas de uso del sistema.
#
# **Respuesta**:
# ```json
# {
#   "total_sessions": 5,
#   "total_messages": 42,
#   "active_sessions": 3
# }
# ```
#
# ---
#
# ### 5. **GET /dashboard** - Dashboard CRM
# Análisis de clientes y oportunidades de venta basado en las conversaciones.
#
# **Respuesta**:
# ```json
# {
#   "total_clients": 5,
#   "hot_leads": 2,
#   "cold_leads": 1,
#   "revenue_potential": "$50,000"
# }
# ```
#
# ---

# %% [markdown]
# ## 💬 Ejemplo 1: Enviar Mensaje al Agente
#
# Vamos a interactuar con la API usando la librería `requests` de Python.

# %%
import requests
import json

# URL base de la API
BASE_URL = "http://localhost:8000"

# Endpoint para chat
url = f"{BASE_URL}/chat"

# Datos a enviar
payload = {
    "message": "¿Qué productos tienen disponibles?",
    "session_id": "test_session_001"
}

# Realizar la petición POST
response = requests.post(url, json=payload)

# Verificar si la petición fue exitosa
if response.status_code == 200:
    data = response.json()
    print("Respuesta del agente:")
    print("=" * 50)
    print(data["response"])
    print("=" * 50)
    print(f"Session ID: {data['session_id']}")
else:
    print(f"Error: {response.status_code}")
    print(response.text)

# %% [markdown]
# ### 💡 Enviar un mensaje de seguimiento
#
# El agente mantiene el contexto de la conversación usando el `session_id`.

# %%
# Segundo mensaje en la misma sesión
payload_2 = {
    "message": "¿Cuál me recomiendas para una startup?",
    "session_id": "test_session_001"  # Mismo session_id para mantener contexto
}

response_2 = requests.post(url, json=payload_2)

if response_2.status_code == 200:
    data = response_2.json()
    print("Respuesta del agente:")
    print("=" * 50)
    print(data["response"])
    print("=" * 50)
else:
    print(f"Error: {response_2.status_code}")

# %% [markdown]
# ## 🗑️ Ejemplo 2: Borrar Historial de Conversación
#
# Podemos limpiar el historial de una sesión específica.

# %%
# Borrar historial de la sesión
session_id = "test_session_001"
delete_url = f"{BASE_URL}/chat/history/{session_id}"

response = requests.delete(delete_url)

if response.status_code == 200:
    data = response.json()
    print("✅", data["message"])
    print(f"Session ID: {data['session_id']}")
else:
    print(f"Error: {response.status_code}")
    print(response.text)

# %% [markdown]
# ## 🆕 Ejemplo 3: Crear Nueva Sesión
#
# Podemos crear una nueva sesión sin especificar un `session_id`, y la API generará uno automáticamente.

# %%
# Crear nueva sesión (sin session_id)
new_session_url = f"{BASE_URL}/chat/new"

payload_new = {
    "message": "Hola, soy un nuevo cliente interesado en sus servicios"
}

response = requests.post(new_session_url, json=payload_new)

if response.status_code == 200:
    data = response.json()
    print("Respuesta del agente:")
    print("=" * 50)
    print(data["response"])
    print("=" * 50)
    print(f"\n🆔 Nuevo Session ID generado: {data['session_id']}")
    print("\n💡 Guarda este session_id para continuar la conversación")
    
    # Guardar el session_id para usarlo después
    nuevo_session_id = data['session_id']
else:
    print(f"Error: {response.status_code}")

# %% [markdown]
# ## 📊 Ejemplo 4: Obtener Estadísticas del Sistema
#
# Podemos consultar las estadísticas de uso de nuestra API.

# %%
# Obtener estadísticas
stats_url = f"{BASE_URL}/stats"

response = requests.get(stats_url)

if response.status_code == 200:
    stats = response.json()
    print("📊 Estadísticas del Sistema")
    print("=" * 50)
    print(f"Total de sesiones: {stats['total_sessions']}")
    print(f"Total de mensajes: {stats['total_messages']}")
    print(f"Sesiones activas: {stats['active_sessions']}")
    print("=" * 50)
else:
    print(f"Error: {response.status_code}")

# %% [markdown]
# ## 📈 Ejemplo 5: Dashboard CRM
#
# El dashboard nos permite analizar las conversaciones y detectar oportunidades de venta.

# %%
# Obtener dashboard CRM
dashboard_url = f"{BASE_URL}/dashboard"

response = requests.get(dashboard_url)

if response.status_code == 200:
    dashboard = response.json()
    print("📈 Dashboard CRM")
    print("=" * 50)
    print(f"Total de clientes: {dashboard.get('total_clients', 0)}")
    print(f"Leads calientes: {dashboard.get('hot_leads', 0)}")
    print(f"Leads fríos: {dashboard.get('cold_leads', 0)}")
    print(f"Potencial de ingresos: {dashboard.get('revenue_potential', 'N/A')}")
    print("=" * 50)
    
    # Mostrar detalles de leads calientes si existen
    if 'hot_lead_details' in dashboard:
        print("\n🔥 Detalles de Leads Calientes:")
        for lead in dashboard['hot_lead_details']:
            print(f"  - {lead}")
else:
    print(f"Error: {response.status_code}")

# %% [markdown]
# ## 🌐 Consumir la API desde HTML/JavaScript
#
# Una de las ventajas principales de tener una API REST es que podemos consumirla desde aplicaciones web. Aquí hay un ejemplo básico de cómo hacerlo:
#
# ### Ejemplo con Fetch API (JavaScript):
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Chat con RAG Agent</title>
# </head>
# <body>
#     <div id="chat-container">
#         <div id="messages"></div>
#         <input type="text" id="user-input" placeholder="Escribe tu mensaje...">
#         <button onclick="sendMessage()">Enviar</button>
#     </div>
#
#     <script>
#         const sessionId = 'web_user_' + Date.now();
#
#         async function sendMessage() {
#             const input = document.getElementById('user-input');
#             const message = input.value;
#
#             // Mostrar mensaje del usuario
#             addMessage('Usuario: ' + message);
#             input.value = '';
#
#             // Enviar a la API
#             const response = await fetch('http://localhost:8000/chat', {
#                 method: 'POST',
#                 headers: {
#                     'Content-Type': 'application/json'
#                 },
#                 body: JSON.stringify({
#                     message: message,
#                     session_id: sessionId
#                 })
#             });
#
#             const data = await response.json();
#             addMessage('Agente: ' + data.response);
#         }
#
#         function addMessage(text) {
#             const messagesDiv = document.getElementById('messages');
#             const messageP = document.createElement('p');
#             messageP.textContent = text;
#             messagesDiv.appendChild(messageP);
#         }
#     </script>
# </body>
# </html>
# ```
#
# ### Consideraciones importantes:
#
# 1. **CORS**: FastAPI debe estar configurado para aceptar peticiones desde el navegador
# 2. **Session Management**: Cada usuario debe tener su propio `session_id`
# 3. **Error Handling**: Implementar manejo de errores para mejorar la experiencia
# 4. **Loading States**: Mostrar indicadores de carga mientras se espera la respuesta
#
# ---

# %% [markdown]
# ## ⚡ Ventajas de V4 vs V3
#
# | Característica | V3 (Notebook) | V4 (FastAPI) |
# |----------------|---------------|---------------|
# | **Acceso** | Solo local en notebook | Desde cualquier aplicación vía HTTP |
# | **Múltiples usuarios** | ❌ | ✅ Sesiones independientes |
# | **Integración web** | ❌ | ✅ HTML/JavaScript |
# | **Escalabilidad** | Limitada | Alta (con despliegue adecuado) |
# | **Persistencia** | Manual | Automática por sesión |
# | **Documentación** | Manual | Automática (Swagger/ReDoc) |
# | **Estadísticas** | ❌ | ✅ Dashboard en tiempo real |
# | **Producción** | No recomendado | Listo para deploy |
# | **Testing** | Complejo | Fácil con requests |
# | **Monitoreo** | ❌ | ✅ Logs y métricas |
#
# ### 🎯 Casos de uso ideales para V4:
#
# 1. **Chatbots web**: Integrar en sitios web corporativos
# 2. **Aplicaciones móviles**: Backend para apps iOS/Android
# 3. **Microservicios**: Parte de una arquitectura más grande
# 4. **CRM integrado**: Análisis de conversaciones con clientes
# 5. **Soporte al cliente**: Sistema de tickets automatizado
# 6. **E-commerce**: Asistente de ventas inteligente
#
# ---

# %% [markdown]
# ## 🚀 Próximos Pasos
#
# ### Para mejorar aún más tu API RAG:
#
# 1. **Autenticación y Autorización**:
#    - Implementar JWT (JSON Web Tokens)
#    - OAuth2 para login social
#    - Rate limiting para prevenir abuso
#
# 2. **Base de Datos**:
#    - PostgreSQL para persistencia de sesiones
#    - Redis para caché de respuestas
#    - MongoDB para logs de conversaciones
#
# 3. **Monitoreo y Logging**:
#    - Prometheus + Grafana para métricas
#    - ELK Stack para logs centralizados
#    - Sentry para tracking de errores
#
# 4. **Despliegue en Producción**:
#    - Docker y Docker Compose
#    - Kubernetes para orquestación
#    - AWS/GCP/Azure para hosting
#    - CI/CD con GitHub Actions
#
# 5. **Mejoras de Rendimiento**:
#    - Caching de embeddings
#    - Async/Await optimizado
#    - Load balancing
#    - CDN para assets estáticos
#
# 6. **Testing**:
#    - Unit tests con pytest
#    - Integration tests
#    - Load testing con Locust
#    - Test coverage > 80%
#
# 7. **Features Avanzadas**:
#    - WebSockets para chat en tiempo real
#    - Streaming de respuestas
#    - Multi-tenancy (múltiples empresas)
#    - A/B testing de prompts
#
# ---
#
# ## 📚 Recursos Adicionales
#
# - [Documentación de FastAPI](https://fastapi.tiangolo.com/)
# - [Tutorial de Uvicorn](https://www.uvicorn.org/)
# - [Guía de Deployment](https://fastapi.tiangolo.com/deployment/)
# - [Best Practices para APIs](https://github.com/microsoft/api-guidelines)
#
# ---
#
# ### ¡Felicitaciones! 🎉
#
# Has aprendido a transformar un agente RAG de notebook a una API REST profesional lista para producción.
#
# **¿Preguntas? ¿Comentarios?**
#
# Continúa experimentando y mejorando tu implementación. El siguiente paso es desplegar esto en la nube y escalarlo para usuarios reales.
